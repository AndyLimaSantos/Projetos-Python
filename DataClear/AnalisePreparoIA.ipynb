# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Vamos importar a biblioteca de dados de IA
dataGross = pd.read_csv("IMF_AI.csv")

# %%
# Out:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.3)      I    A      AGO
# 1  datastructure  WB.DATA360:DS_DATA360(1.3)      I    A      ALB
# 2  datastructure  WB.DATA360:DS_DATA360(1.3)      I    A      ARE
# 3  datastructure  WB.DATA360:DS_DATA360(1.3)      I    A      ARG
# 4  datastructure  WB.DATA360:DS_DATA360(1.3)      I    A      ARM
#
#         INDICATOR SEX AGE URBANISATION UNIT_MEASURE  ...  \
# 0  IMF_AI_AIPI_IX  _Z  _Z           _Z       0_TO_1  ...
# 1  IMF_AI_AIPI_IX  _Z  _Z           _Z       0_TO_1  ...
# 2  IMF_AI_AIPI_IX  _Z  _Z           _Z       0_TO_1  ...
# 3  IMF_AI_AIPI_IX  _Z  _Z           _Z       0_TO_1  ...
# 4  IMF_AI_AIPI_IX  _Z  _Z           _Z       0_TO_1  ...
#
#   COMP_BREAKDOWN_1_LABEL COMP_BREAKDOWN_2_LABEL COMP_BREAKDOWN_3_LABEL  \
# 0         Not Applicable         Not Applicable         Not Applicable
# 1         Not Applicable         Not Applicable         Not Applicable
# ...
