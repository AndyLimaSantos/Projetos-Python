# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
valores = np.random.randint(1,101,100).reshape(10,10) #criação de uma lista com valores aleatórios
linha = "A,B,C,D,E,F,G,H,I,J".split(",")
coluna = "anderson,larissa,robson,helenice,renilton,roberto,isabela,rodolfo,kleiton,luiz".split(",")

# %%
data = pd.DataFrame(data = valores, index = linha, columns = coluna) #criação do dataframe
data
# Out:
#    anderson  larissa  robson  helenice  renilton  roberto  isabela  rodolfo  \
# A        56       38      89        44        80       55       37       14
# B        59       95       1        22        32        1       13       26
# C        48       72      47        35        95        1       60       55
# D         7       49       6        14         1       55       16       98
# E        76       69      38        59        95       18       37       82
# F        69      100      75        40        83       73       64       37
# G         5       89      49        77        20       56       37       51
# H        26       74      35        26         1       81       35       63
# I        49       85      58        58        22       45       68       65
# J        58       91      29        46        33       78       36       64
#
#    kleiton  luiz
# A        4    91
# B        4    45
# C       88    93
# D       63    67
# E       33    37
# F        1    41
# ...

# %%
data.plot()
plt.show()

# %%
data.boxplot() #da a região onde os dados estão localizados
plt.show()
data["anderson"].mean()
# Out:
# np.float64(45.3)

# %%
pd.plotting.autocorrelation_plot(s_anderson)
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
pd.plotting.radviz(data, "robson")
# Out:
# <Axes: >

# %%
pd.plotting.scatter_matrix(data[["anderson","larissa","robson"]], alpha=0.9)
# Out:
# array([[<Axes: xlabel='anderson', ylabel='anderson'>,
#         <Axes: xlabel='larissa', ylabel='anderson'>,
#         <Axes: xlabel='robson', ylabel='anderson'>],
#        [<Axes: xlabel='anderson', ylabel='larissa'>,
#         <Axes: xlabel='larissa', ylabel='larissa'>,
#         <Axes: xlabel='robson', ylabel='larissa'>],
#        [<Axes: xlabel='anderson', ylabel='robson'>,
#         <Axes: xlabel='larissa', ylabel='robson'>,
#         <Axes: xlabel='robson', ylabel='robson'>]], dtype=object)

# %%
data.pie()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26288\1244221816.py in ?()
# ----> 1 data.pie()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pie'
